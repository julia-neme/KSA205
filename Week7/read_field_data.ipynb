# %% [markdown]
# This code will read in the field data from the KSA205 data template. Be sure to use the name of your file and check the sheet name is `Final data`.
#
# Replace the right hand side of the next line with your file name (making sure it is in the same folder as this script):

# %%
import pandas as pd

# %%
data = pd.read_excel('KSA205_2024_FieldDataCompilation_FINAL.xlsx', sheet_name = '4. Final data to share', skiprows = 7)

# %%
data
# Out:
#                                      Group members  Latitude  Longitude  \
# 0                    Santa, Rudolph and Mrs Clause  -30.5000   140.0000
# 1                Ruby, Ruby, Titus,  Bridie, leila  -42.8800   147.3300
# 2            Grace, Georgia, Rodrigo, Camille, Ann  -42.8859   147.3357
# 3        Ethan, Amelia, Lydia, Jackson, Ali, arwyn  -42.8859   147.3358
# 4                           Facebook market place   -42.8859   147.3358
# 5                   sheng, Wan, Bryan, ben, Jordan  -42.8860   147.3364
# 6             Mila, Angus, Darcy, Armirah and Finn  -42.8859   147.3364
# 7   Lauren, Cam, Sasha, Octavius, Ashalynn, Alyssa  -42.8860   147.2264
# 8                        Bianca, Hugo, Tully, Jude  -42.8660   147.3364
# 9                                   Pacific Crest   -42.8861   147.3364
# 10                                Spirit of Hobart  -42.8859   147.3364
# 11                                        Botto Ox  -42.8858   147.3365
# ...

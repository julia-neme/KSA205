# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
LR04 = pd.read_csv('LR04.csv')
c1088 = pd.read_csv('Leg177_Site_1088.csv')
c1089 = pd.read_csv('Leg177_1089.csv')

# %%
LR04
# Out:
#       Time (ka)  Benthic d18O (per mil)  Standard error (per mil)
# 0           0.0                    3.23                      0.03
# 1           1.0                    3.23                      0.04
# 2           2.0                    3.18                      0.03
# 3           3.0                    3.29                      0.03
# 4           4.0                    3.30                      0.03
# ...         ...                     ...                       ...
# 2110     5300.0                    2.91                      0.06
# 2111     5305.0                    2.79                      0.04
# 2112     5310.0                    2.79                      0.09
# 2113     5315.0                    2.84                      0.07
# 2114     5320.0                    2.91                      0.09
#
# [2115 rows x 3 columns]

# %%
plt.plot(LR04['Time (ka)'], LR04['Benthic d18O (per mil)'])
plt.xlim(0, 500)
plt.gca().invert_yaxis();
plt.xlabel('Time (ka)');
plt.ylabel('d180');

# %% [markdown]
# Plot for Part 2 d18O and CaCo3 with depth.
#
# Change the depths and datafiles

# %%
fig, axs = plt.subplots(1, 2, figsize = (15,5))
axs[0].plot(c1088['Depth sed [m]'], c1088['CaCO3 [%]'])
axs[0].set_xlim(0, 4)
axs[0].set_xlabel('Depth (m)')
axs[0].set_ylabel('CaCO3 (%)')

axs[1].plot(c1088['Depth sed [m]'], c1088['Cibicidoides spp. δ18O [‰ PDB]'])
axs[1].set_xlim(0, 4)
axs[1].set_xlabel('Depth (m)')
axs[1].set_ylabel('d180')

plt.gca().invert_yaxis()

# %% [markdown]
# A simple script to read in CTD data collected with the mini CTD (Castaway) used in the KSA205 field trip. Make sure this script and your CTD data file are in the same directory.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Replace `CC2225003_20240411_000406` with the name of the file you're plotting

# %%
data = pd.read_csv('first_trip/CC2225003_20240411_000406.csv', skiprows = 28)
data
# Out:
#     Pressure (Decibar)  Depth (Meter)  Temperature (Celsius)  \
# 0              0.15000       0.149605              16.640311
# 1              0.45000       0.448808              16.747608
# 2              0.75000       0.747928              16.869827
# 3              1.05000       1.046947              16.931309
# 4              1.35000       1.345911              16.977882
# ..                 ...            ...                    ...
# 59            17.85000      17.764560              17.589926
# 60            18.15000      18.062953              17.593104
# 61            18.45000      18.361347              17.593199
# 62            18.75000      18.659739              17.595505
# 63            18.99531      18.903735              17.602469
#
#     Conductivity (MicroSiemens per Centimeter)  \
# 0                                  40142.53242
# 1                                  40331.63514
# 2                                  41280.73980
# 3                                  41611.03981
# 4                                  41977.52022
# ..                                         ...
# 59                                 45506.78097
# 60                                 45509.95250
# 61                                 45513.06372
# 62                                 45521.09693
# 63                                 45520.47520
#
#     Specific conductance (MicroSiemens per Centimeter)  \
# 0                                         48201.52812
# 1                                         48304.12733
# 2                                         49296.52550
# 3                                         49618.10281
# 4                                         49999.56958
# ..                                                ...
# 59                                        53424.34808
# 60                                        53424.08498
# 61                                        53427.61821
# 62                                        53434.15549
# 63                                        53424.69191
#
#     Salinity (Practical Salinity Scale)  Sound velocity (Meters per Second)  \
# 0                             31.162820                         1507.344675
# 1                             31.242656                         1507.769244
# 2                             31.966032                         1508.974569
# 3                             32.202174                         1509.436277
# 4                             32.481189                         1509.901428
# ..                                  ...                                 ...
# 59                            35.009857                         1514.892215
# 60                            35.009734                         1514.906441
# 61                            35.012220                         1514.914542
# 62                            35.017041                         1514.931831
# 63                            35.010402                         1514.948886
#
#     Density (Kilograms per Cubic Meter)
# 0                           1022.655688
# 1                           1022.693717
# 2                           1023.221503
# 3                           1023.389623
# 4                           1023.594027
# ..                                  ...
# 59                          1025.459545
# 60                          1025.459997
# 61                          1025.463199
# 62                          1025.467654
# 63                          1025.461949
#
# [64 rows x 8 columns]

# %%
pressure = data.iloc[:,0]
depth = data.iloc[:,1] 
temperature = data.iloc[:,2]
salinity = data.iloc[:,5] 
density = data.iloc[:,7]

# %%
fig, axs = plt.subplots(1, 3, figsize = (12, 4))
axs[0].plot(salinity, depth, color = 'k', marker = 'o')
axs[1].plot(temperature, depth, color = 'r', marker = 'o')
axs[2].plot(density, depth, color = 'b', marker = 'o')
# Invert axis:
for ax in axs:
    ax.invert_yaxis();
    # Add depth label
    ax.set_ylabel('Depth (m)')
# Add labels
axs[0].set_xlabel('Salinity')
axs[1].set_xlabel('Temperature ($^{\\circ}$C)')
axs[2].set_xlabel('Density (kg/m$^3$)');
# Save figure (remember to change names if you are doing multiple plots to avoid overwriting)
plt.savefig('profile.jpg', bbox_inches = 'tight')
